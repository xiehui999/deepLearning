# %%
#淘宝抓取

#
#https://uland.taobao.com/sem/tbsearch?spm=a2e15.8261149.07626516003.1.13ec29b4m5CgtQ&refpid=mm_15891853_2192459_8654707&clk1=7e8ac9911bceac00655ba5e997d8d8bf&keyword=java&page=2&_input_charset=utf-8
import urllib
import urllib.request
import ssl

# SSLError
ssl._create_default_https_context = ssl._create_unverified_context
url="https://uland.taobao.com/sem/tbsearch?refpid=mm_15891853_2192459_8654707&clk1=7e8ac9911bceac00655ba5e997d8d8bf&keyword=java&page=0"
data=urllib.request.urlopen(url).read().decode("utf-8","ignore")
##输出请求结果长度
data
# Out:
# '\r\n\r\n<!DOCTYPE html>\n<html>\n    <head><script src="//g.alicdn.com/lego2/wpkignores/i.js"></script><script src="//g.alicdn.com/cell/wpk/0.0.2/wpk.js"></script><script>try{getLego2WPK({"bid":"","env":""})}catch(e){function getLego2WPK(){return {report:noop,reportFlow:noop,reportError:noop,reportApiError:noop,setConfig:noop,install:noop,installAll:noop,uninstall:noop,diagnose:noop};function noop(){}}}</script>\n        <meta charset="utf-8"/>\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n        <meta name="renderer" content="webkit" />\n        <meta name="data-spm" content="a2e15" />\n        <title>淘宝网热卖</title>\n        <link rel="stylesheet" href="//g.alicdn.com/??thx/cube/1.2.2/cube-https-min.css">\n        <link rel="stylesheet" type="text/css" href="//g.alicdn.com/mm/semlanding-pc-magixcell/0.0.12/tbsearch/index.css">\n      \t<script typescri ="text/javascript" src="https://g.alicdn.com/dt/tracker/3.4.11/??tracker.Tracker.js,tracker.interfaceT
# ...
